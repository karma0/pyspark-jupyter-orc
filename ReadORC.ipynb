# %%
import pyspark
sc = pyspark.SparkContext('local[*]')

# %%
# do something to prove it works
rdd = sc.parallelize(range(1000))
rdd.takeSample(False, 5)
# Out:
# [931, 623, 136, 175, 526]

# %%
from pyspark.context import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

spark = SparkSession.builder \
        .master("local") \
        .appName("Row Count") \
        .getOrCreate()
#         .config("spark.some.config.option", "some-value") \

# %%
df = spark.read.orc("./siphoncrypto-exchange-ccxt-ohlcv-1-2018-09-02-00-51-25-c72f4e61-d2e1-44cf-8687-7bfca3a3afdf.orc")
df.head()
# Out:
# Row(ts=None, server_ts=None, market='BTC/USD', exchange='bittrex', open=6420.0, high=6420.0, low=6420.0, close=6420.0, volume=0.001383490045554936)

# %%
df = spark.read.orc("siphoncrypto-exchange-ccxt-ohlcv-1-2018-09-05-23-12-57-ebd5027c-fded-4760-8d04-e52533e61832.orc")

# %%
df.select(df.columns).collect()
# Out:
# [Row(ts=1536189177.6081321, server_ts=1536088380000.0, market='BTC/USD', exchange='bittrex', open=7352.93310546875, high=7352.93310546875, low=7349.376953125, close=7349.376953125, volume=0.002508539939299226),
#  Row(ts=1536189177.6192558, server_ts=1536088740000.0, market='BTC/USD', exchange='bittrex', open=7349.376953125, high=7349.376953125, low=7349.376953125, close=7349.376953125, volume=0.027928009629249573),
#  Row(ts=1536189177.629257, server_ts=1536088920000.0, market='BTC/USD', exchange='bittrex', open=7347.216796875, high=7347.216796875, low=7345.15087890625, close=7345.15087890625, volume=0.008136429823935032),
#  Row(ts=1536189177.6416678, server_ts=1536088980000.0, market='BTC/USD', exchange='bittrex', open=7350.1728515625, high=7350.1728515625, low=7344.36083984375, close=7344.36083984375, volume=0.1850913166999817),
# ...
